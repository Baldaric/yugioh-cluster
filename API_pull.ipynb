# %% [markdown]
# # Import Libraries

# %%
import requests
import json
import pandas as pd

# %% [markdown]
# # Data Loading

# %% [markdown]
# ## YgoPro API (no need to rerun)

# %%
# url = "https://db.ygoprodeck.com/api/v7/cardinfo.php"

# Response = requests.get(url)

# if Response.status_code == 200:
#     Cards = Response.json().get("data", [])

#     with open("yugioh_cards.json", "w") as f:
#         json.dump(Cards, f, indent=4)
    
#     print(f"Saved {len(Cards)} cards locally.")
# else:
#     print("Error fetching data:", Response.status_code)

# %%
df = pd.read_json('yugioh_cards.json')

# %%
df.head(5)
# Out:
#          id                           name        type humanReadableCardType  \
# 0  34541863       "A" Cell Breeding Device  Spell Card      Continuous Spell
# 1  64163367             "A" Cell Incubator  Spell Card      Continuous Spell
# 2  91231901  "A" Cell Recombination Device  Spell Card      Quick-Play Spell
# 3  73262676         "A" Cell Scatter Burst  Spell Card      Quick-Play Spell
# 4  98319530     "Infernoble Arms - Almace"  Spell Card           Equip Spell
#
#   frameType                                               desc        race  \
# 0     spell  During each of your Standby Phases, put 1 A-Co...  Continuous
# 1     spell  Each time an A-Counter(s) is removed from play...  Continuous
# 2     spell  Target 1 face-up monster on the field; send 1 ...  Quick-Play
# 3     spell  Select 1 face-up "Alien" monster you control. ...  Quick-Play
# 4     spell  While this card is equipped to a monster: You ...       Equip
#
#          archetype                                     ygoprodeck_url  \
# 0            Alien  https://ygoprodeck.com/card/a-cell-breeding-de...
# 1            Alien  https://ygoprodeck.com/card/a-cell-incubator-8856
# 2            Alien  https://ygoprodeck.com/card/a-cell-recombinati...
# 3            Alien  https://ygoprodeck.com/card/a-cell-scatter-bur...
# 4  Infernoble Arms  https://ygoprodeck.com/card/infernoble-arms-al...
#
#                                            card_sets  ... atk def level  \
# 0  [{'set_name': 'Force of the Breaker', 'set_cod...  ... NaN NaN   NaN
# 1  [{'set_name': 'Gladiator's Assault', 'set_code...  ... NaN NaN   NaN
# 2  [{'set_name': 'Invasion: Vengeance', 'set_code...  ... NaN NaN   NaN
# 3  [{'set_name': 'Strike of Neos', 'set_code': 'S...  ... NaN NaN   NaN
# 4  [{'set_name': 'Duelist Nexus', 'set_code': 'DU...  ... NaN NaN   NaN
#
#    attribute  linkval  linkmarkers pend_desc  monster_desc scale banlist_info
# 0        NaN      NaN          NaN       NaN           NaN   NaN          NaN
# 1        NaN      NaN          NaN       NaN           NaN   NaN          NaN
# 2        NaN      NaN          NaN       NaN           NaN   NaN          NaN
# 3        NaN      NaN          NaN       NaN           NaN   NaN          NaN
# 4        NaN      NaN          NaN       NaN           NaN   NaN          NaN
#
# [5 rows x 23 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13567 entries, 0 to 13566
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     13567 non-null  int64
#  1   name                   13567 non-null  object
#  2   type                   13567 non-null  object
#  3   humanReadableCardType  13567 non-null  object
#  4   frameType              13567 non-null  object
#  5   desc                   13567 non-null  object
#  6   race                   13567 non-null  object
#  7   archetype              8043 non-null   object
#  8   ygoprodeck_url         13567 non-null  object
#  9   card_sets              13097 non-null  object
#  10  card_images            13567 non-null  object
#  11  card_prices            13567 non-null  object
#  12  typeline               8712 non-null   object
#  13  atk                    8712 non-null   float64
#  14  def                    8286 non-null   float64
#  15  level                  8391 non-null   float64
#  16  attribute              8712 non-null   object
#  17  linkval                428 non-null    float64
#  18  linkmarkers            428 non-null    object
#  19  pend_desc              343 non-null    object
#  20  monster_desc           343 non-null    object
#  21  scale                  357 non-null    float64
#  22  banlist_info           297 non-null    object
# dtypes: float64(5), int64(1), object(17)
# memory usage: 2.4+ MB

# %%
df2 = df[['id','name','frameType','desc','race','archetype']]

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13567 entries, 0 to 13566
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   id         13567 non-null  int64
#  1   name       13567 non-null  object
#  2   frameType  13567 non-null  object
#  3   desc       13567 non-null  object
#  4   race       13567 non-null  object
#  5   archetype  8043 non-null   object
# dtypes: int64(1), object(5)
# memory usage: 636.1+ KB

# %%
df2.head()
# Out:
#          id                           name frameType  \
# 0  34541863       "A" Cell Breeding Device     spell
# 1  64163367             "A" Cell Incubator     spell
# 2  91231901  "A" Cell Recombination Device     spell
# 3  73262676         "A" Cell Scatter Burst     spell
# 4  98319530     "Infernoble Arms - Almace"     spell
#
#                                                 desc        race  \
# 0  During each of your Standby Phases, put 1 A-Co...  Continuous
# 1  Each time an A-Counter(s) is removed from play...  Continuous
# 2  Target 1 face-up monster on the field; send 1 ...  Quick-Play
# 3  Select 1 face-up "Alien" monster you control. ...  Quick-Play
# 4  While this card is equipped to a monster: You ...       Equip
#
#          archetype
# 0            Alien
# 1            Alien
# 2            Alien
# 3            Alien
# 4  Infernoble Arms

# %%
df2 = df2.iloc[:, [0,1,2,4,5,3]]

# %%
df2.head()
# Out:
#          id                           name frameType        race  \
# 0  34541863       "A" Cell Breeding Device     spell  Continuous
# 1  64163367             "A" Cell Incubator     spell  Continuous
# 2  91231901  "A" Cell Recombination Device     spell  Quick-Play
# 3  73262676         "A" Cell Scatter Burst     spell  Quick-Play
# 4  98319530     "Infernoble Arms - Almace"     spell       Equip
#
#          archetype                                               desc
# 0            Alien  During each of your Standby Phases, put 1 A-Co...
# 1            Alien  Each time an A-Counter(s) is removed from play...
# 2            Alien  Target 1 face-up monster on the field; send 1 ...
# 3            Alien  Select 1 face-up "Alien" monster you control. ...
# 4  Infernoble Arms  While this card is equipped to a monster: You ...
